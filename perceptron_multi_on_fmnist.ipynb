# %% [markdown]
# <a href="https://colab.research.google.com/github/datgerhardt/ml-foundations/blob/main/perceptron_multi_on_fmnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Data preprocessing
from tensorflow.keras.datasets import fashion_mnist 
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = [x/255 for x in [x_train, x_test]]
y_train, y_test = [tf.keras.utils.to_categorical(x) for x in [y_train, y_test]]
img_width, img_height = x_train.shape[1], x_train.shape[2]

num_classes = 10
labels = ["T-shirt/top", "Trouser", "Pullover", "Dress",
          "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

print("X : ",x_train.shape, x_test.shape)
print("Y : ",y_train.shape, y_test.shape)
# Out:
# X :  (60000, 28, 28) (10000, 28, 28)
# Y :  (60000, 10) (10000, 10)

# %%
figsize(16,16)
figure()
imshow(np.concatenate(gm.predict(np.random.normal(size=(10,ZDIM))), axis=1))
plt.show()

# %%
# build model
model=Sequential()
model.add(Flatten(input_shape=(img_width,img_height)))
model.add(Dropout(0.4))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
hist = model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6978 - accuracy: 0.7472 - val_loss: 0.4817 - val_accuracy: 0.8252
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5382 - accuracy: 0.8025 - val_loss: 0.4528 - val_accuracy: 0.8311
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5048 - accuracy: 0.8151 - val_loss: 0.4404 - val_accuracy: 0.8376
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4894 - accuracy: 0.8185 - val_loss: 0.4129 - val_accuracy: 0.8511
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4780 - accuracy: 0.8235 - val_loss: 0.4095 - val_accuracy: 0.8506
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4710 - accuracy: 0.8253 - val_loss: 0.4008 - val_accuracy: 0.8528
# Epoch 7/50
# ...

# %%
def display(history):
  plt.subplots(figsize=(12, 4))
  plt.subplot(1,2,1)
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  # summarize history for loss
  plt.subplot(1,2,2)
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')

# %%
display(hist)

# %%
display(hist) # training for 50 epochs

# %%
display(hist) # Adding dropout

# %%
display(hist) # Adding dropout for 50 epochs

# %%
display(hist) # change mse loss  to categorical cross entropy for 10 epochs

# %%
display(hist) # change mse loss  to categoricalcross entropy activation func for 50 epochs
